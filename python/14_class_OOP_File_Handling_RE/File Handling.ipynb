# %%
[1,2,3]
[A,B,C]
[C,B,A, 3,2,1]

# %%
with open("abc.txt", 'r+') as f:
    a = list(reversed(f.readlines()))
    print("A",a)
    b = list(reversed(['A',"B","C"]))
    print("B",b)
    c = a + b
    print("C",c)
    d = " ".join(c)
    print("D",d)
    f.seek(0) # set cursor index postion
    f.write(d)# write here
# Out:
# A ['[C,B,A, 3,2,1]\n', '[A,B,C]\n', '[1,2,3]\n']
# B ['C', 'B', 'A']
# C ['[C,B,A, 3,2,1]\n', '[A,B,C]\n', '[1,2,3]\n', 'C', 'B', 'A']
# D [C,B,A, 3,2,1]
#  [A,B,C]
#  [1,2,3]
#  C B A

# %%
with open("abc.txt", 'r') as f:
    a = list(reversed(f.readlines()))
    print("A",a)
    b = list(reversed(['A',"B","C"]))
    print("B",b)
    c = a + b
    print("C",c)
    d = " ".join(c)
    print("D",d)
    f.seek(0) # set cursor index postion
    f.write(d)# write here
# Out:
# A [' C B A', ' [1,2,3]\n', ' [A,B,C]\n', '[C,B,A, 3,2,1]\n']
# B ['C', 'B', 'A']
# C [' C B A', ' [1,2,3]\n', ' [A,B,C]\n', '[C,B,A, 3,2,1]\n', 'C', 'B', 'A']
# D  C B A  [1,2,3]
#   [A,B,C]
#  [C,B,A, 3,2,1]
#  C B A
# ----------------------------------------------------------------------
# UnsupportedOperation                 Traceback (most recent call last)
# <ipython-input-4-4f9bb1765492> in <module>
#       9     print("D",d)
#      10     f.seek(0) # set cursor index postion
# ---> 11     f.write(d)# write here
#
# UnsupportedOperation: not writable

# %% [raw]
#                   | r   r+   w   w+   a   a+
# ------------------|--------------------------
# read              | +   +        +        +
# write             |     +    +   +    +   +
# write after seek  |     +    +   +
# create            |          +   +    +   +
# truncate          |          +   +
# position at start | +   +    +   +
# position at end   |                   +

# %%
open("abc.txt")
# Out:
# <_io.TextIOWrapper name='abc.txt' mode='r' encoding='UTF-8'>

# %%
list(open("abc.txt"))
# Out:
# ['[C,B,A, 3,2,1]\n', ' [A,B,C]\n', ' [1,2,3]\n', ' C B A']

# %%
d = open("abc1.txt")# glass uthao
print(list(d))# pani piyo
d.close()# glass wapis rakho
# Out:
# ['Line1\n', 'Line2\n', 'Line3\n', 'Line4\n', 'Line5\n']

# %%
d = open("abc1.txt")# glass uthao
print(list(d))# pani piyo
# Out:
# ['abc\n', 'xyz\n']

# %%
# with open(file) as <variable>
with open("abc.txt") as file:
    content = file.read()
    print(type(content))
    print(content)

print("Hello World")
# Out:
# <class 'str'>
# [C,B,A, 3,2,1]
#  [A,B,C]
#  [1,2,3]
#  C B A
# Hello World

# %%
# with open(file) as <variable>
with open("abc.txt") as file:
    content = file.readline()# read first line
    print(type(content))
    print(content)
# Out:
# <class 'str'>
# [C,B,A, 3,2,1]

# %%
# with open(file) as <variable>
with open("abc.txt") as file:
    content = file.readlines()# read all lines make a list
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ['[C,B,A, 3,2,1]\n', ' [A,B,C]\n', ' [1,2,3]\n', ' C B A']

# %%
# with open(file) as <variable>
with open("abc.txt") as file:
    content = file.readlines()[:2]
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ['[C,B,A, 3,2,1]\n', ' [A,B,C]\n']

# %%
# with open(file) as <variable>
with open("abc1.txt") as file:
    content = file.readlines()[:2]
    file.write("Paikistan zindabad!")# break rule / try to write with wrong mode "r"
    print(type(content))
    print(content)
# Out:
# ----------------------------------------------------------------------
# UnsupportedOperation                 Traceback (most recent call last)
# <ipython-input-19-5d4a73779536> in <module>
#       2 with open("abc1.txt") as file:
#       3     content = file.readlines()[:2]
# ----> 4     file.write("Paikistan zindabad!")# break rule / try to write with wrong mode "r"
#       5     print(type(content))
#       6     print(content)
#
# UnsupportedOperation: not writable

# %%
with open("abc1.txt", mode='w') as f:
    content = f.readlines()# rule break / try to read with "w" not allowed
    print(content)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-19-79bbc6281410> in <module>
#       1 with open("abc2.txt", mode='w') as f:
# ----> 2     content = f.readlines()
#       3     print(content)
#
# UnsupportedOperation: not readable

# %%
with open("abc2.txt", mode='w') as f:
    f.write("Pakista zinda bad!")

# %%
with open("abc2.txt", mode='w') as f: # write truncate concept
    f.write("We are Pakistani!")

# %%
with open("abc3.txt", 'a') as f:
    f.write("\nHello World1!")

# %%
with open("abc3.txt", 'a') as f:
    f.write("\nHello World2!")

# %%
with open("abc3.txt", 'a') as f:
    f.write("\nHello World3!")

# %%
with open("abc4.txt", 'a+') as f:
    f.write("Hello World3\n!")
    f.seek(0)# cursor postion set at start 
    c = f.readlines()# we can also read with "a+"
    print(c)
# Out:
# ['Hello World3\n', '!']

# %%
open('abc6.txt', 'x')
# Out:
# <_io.TextIOWrapper name='abc6.txt' mode='x' encoding='UTF-8'>

# %%
open('abc6.txt', 'x')
# Out:
# ----------------------------------------------------------------------
# FileExistsError                      Traceback (most recent call last)
# <ipython-input-27-2dd2ac3e5142> in <module>
# ----> 1 open('abc6.txt', 'x')
#
# FileExistsError: [Errno 17] File exists: 'abc6.txt'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('files/a.jpg')# read image
# print(img.shape)#
plt.imshow(img)# display image

# %%
from PIL import Image
image = Image.open("./files/hamza.png")
image.show()

# %%
# pip install opencv-python
import cv2
image = cv2.imread('./files/hamza.png')
plt.imshow(image)
plt.show()

# %%
import cv2
im = cv2.imread("./files/a.jpg" )
#im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
import cv2
im = cv2.imread("./files/a.jpg" )
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)  
im.shape
plt.imshow(im)

# %%
from tensorflow.keras.preprocessing import image

X_test=image.load_img('./files/a.jpg',target_size=(28,28),color_mode="rgb"); #loading image and then convert it into grayscale and with it's target size 
X_test=image.img_to_array(X_test); #convert image into array
print(X_test.shape)
plt.imshow(X_test/255)
# Out:
# (28, 28, 3)

# %%
import numpy as np
im = np.array(Image.open('./files/a.jpg').convert('L'))
plt.imshow(im)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(im, cmap=plt.get_cmap('gray'))

# %%
from scipy.io import wavfile
rate1,dat1 = wavfile.read('./files/audio.wav')
print(rate1)
print(dat1)
# Out:
# 8000
# [[ -114    23]
#  [ -241     3]
#  [ -285   -29]
#  ...
#  [ -772 -1059]
#  [ -422  -840]
#  [ -787  -314]]
# /home/mqasim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: WavFileWarning: Chunk (non-data) not understood, skipping it.

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys


spf = wave.open("./files/audio.wav", "r")
# Extract Raw Audio from Wav File
signal = spf.readframes(-1)
signal = np.fromstring(signal, "Int16")

plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()
# Out:
# /home/mqasim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # Remove the CWD from sys.path while we load stuff.
# /home/mqasim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ----------------------------------------------------------------------
# error                                Traceback (most recent call last)
# <ipython-input-46-f0bf06cf872b> in <module>
#       6 while(True):
#       7     ret, frame = cap.read()
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9
#      10     cv2.imshow('frame',gray)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-7m_g9lbm/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ----------------------------------------------------------------------
# error                                Traceback (most recent call last)
# <ipython-input-2-9c1a600697e9> in <module>
#       6 while(True):
#       7     ret, frame = cap.read()
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#       9
#      10     cv2.imshow('frame',gray)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-7m_g9lbm/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2

cap = cv2.VideoCapture("./files/mov_bbb.mp4")
ret, frame = cap.read()
while(1):
   ret, frame = cap.read()
   cv2.imshow('frame',frame)
   if cv2.waitKey(2) & 0xFF == ord('q') or ret==False :
       cap.release()
       cv2.destroyAllWindows()
       break
   cv2.imshow('frame',frame)
# Out:
# ----------------------------------------------------------------------
# error                                Traceback (most recent call last)
# <ipython-input-1-1d11c90de47d> in <module>
#       5 while(1):
#       6    ret, frame = cap.read()
# ----> 7    cv2.imshow('frame',frame)
#       8    if cv2.waitKey(2) & 0xFF == ord('q') or ret==False :
#       9        cap.release()
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-7m_g9lbm/opencv/modules/highgui/src/window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
import pandas as pd

df = pd.read_excel("./files/data.xlsx")
df.head()
# Out:
#   Unnamed: 0 TRIAL BALANCE AS ON 30 JUN,2018                    Unnamed: 2  \
# 0        NaN                             NaN                           NaN
# 1       CODE   T      I      T      L      E                         DEBIT
# 2    10-0000                             NaN                        ASSETS
# 3    11-0000                             NaN                CURRENT ASSETS
# 4    11-0100                             NaN        CASH AND BANK BALANCES
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1     CREDIT        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df = pd.read_json("https://jsonplaceholder.typicode.com/todos/")
df
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %%
open??

# %%
# %load a.py
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# %pwd
# Out:
# '/home/muhammadqasim/WindowData/PIAIC/ISLAMABAD/9 to 12/python/class9(File Handling)'
